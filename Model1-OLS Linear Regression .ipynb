# %%
[ ]
# Model-1: Linear Regression (OLS for significance + sklearn for prediction)

import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

# Load dataset
…
# Boolean → int
bool_cols = df.select_dtypes(include="bool").columns
for col in bool_cols:
    df[col] = df[col].astype(int)

# Ordinal Encoding
df["AcademicLevelEndofTerm"] = df["AcademicLevelEndofTerm"].replace({
    "Freshman": 1, "Sophomore": 2, "Junior": 3,
    "Senior": 4, "Graduate": 5, "Masters": 6

/tmp/ipython-input-2632555069.py:38: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
  df["AcademicLevelEndofTerm"] = df["AcademicLevelEndofTerm"].replace({

Regression Equation:
CumulativeGPA = 0.9997 + 0.0009 * Age - 0.0122 * NumberofClassesEnrolled + 0.0299 * UnitsPassednotincludedinGPA + 0.0712 * AcademicLevelEndofTerm + 0.0044 * AcademicYear + 0.6665 * TermGPA - 0.0012 * Gender_Male + 0.0452 * Gender_Unknown - 0.1708 * PrimaryMilitaryAffiliation_Child Dependent - 0.0926 * PrimaryMilitaryAffiliation_Guard Reserve - 0.1248 * PrimaryMilitaryAffiliation_No Military Affiliation - 0.0782 * PrimaryMilitaryAffiliation_Other Dependent - 0.0801 * PrimaryMilitaryAffiliation_Spouse Dependent - 0.1116 * PrimaryMilitaryAffiliation_Unknown Military Affiliation - 0.1125 * PrimaryMilitaryAffiliation_Veteran + 0.0441 * College_Coll of Ag Life & Env Sci + 0.0188 * College_College of Applied Sci & Tech + 0.0232 * College_College of Education + 0.0142 * College_College of Engineering + 0.0216 * College_College of Fine Arts - 0.1707 * College_College of Humanities + 0.0058 * College_College of Information Science + 0.0309 * College_College of Medicine - Phoenix + 0.0584 * College_College of Medicine - Tucson + 0.0667 * College_College of Nursing - 0.1148 * College_College of Science - 0.0489 * College_College of Social & Behav Sci - 0.4243 * College_Colleges of Letters Arts & Sci - 0.0246 * College_Eller College of Management - 0.1372 * College_Graduate College + 0.0047 * College_James C Wyant Coll Optical Sci - 0.1637 * College_R Ken Coit College of Pharmacy + 0.0480 * College_Undergraduate Education - 0.0079 * College_Zuckerman Coll Public Health - 0.0393 * FirstGenerationFlag_Y - 0.1434 * AcademicCareer_Law

Excel file saved at: /content/Model1_OLS_Results.xlsx
